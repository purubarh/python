# %%
1+1
3+4
# Out:
# 7

# %%
print ("Hello !! Canada")
# Out:
# Hello !! Canada

# %%
print ("good bye")
# Out:
# good bye

# %%
print("Hello Arnavi")
# Out:
# Hello Arnavi

# %%
print("First Live learning session!")
# Out:
# First Live learning session!

# %%
# Integers are whole number
1+4
# Out:
# 5

# %%
#FLOATING POINT (float) are decimal numbers
5/2
# Out:
# 2.5

# %%
type(2.5)
# Out:
# float

# %%
type (5/2)
# Out:
# float

# %%
# Mod - Integer division(Always Rounding Down)
10//3
# Out:
# 3

# %%
10/3
# Out:
# 3.3333333333333335

# %%
# Module % -Remainder Value
10%3
# Out:
# 1

# %%
#Exponentiation
10**3
# Out:
# 1000

# %%
50 > 25
# Out:
# True

# %%
4**1/2
# Out:
# 2.0

# %%
type(64**(1/2))
# Out:
# float

# %%
# Variable can include digits, letters and underscores
# but cannot start with a digit 
# and case sensitive

degree_celsius = 25

# %%
degree_celsius
# Out:
# 25

# %%
degrees_fahrenheit = (9 / 5) * degree_celsius + 32

# %%
degrees_fahrenheit
# Out:
# 77.0

# %%
degree_celsius = 0

# %%
degree_celsius
# Out:
# 0

# %%
degrees_fahrenheit
# Out:
# 77.0

# %%
degrees_fahrenheit = (9 / 5) * degree_celsius + 32

# %%
degrees_fahrenheit
# Out:
# 32.0

# %%
degree_celsius = degree_celsius + 10

# %%
degree_celsius
# Out:
# 10

# %%
degree_celsius = degree_celsius + 10

# %%
degree_celsius
# Out:
# 20

# %%
a=1
b=a
a
b
# Out:
# 1

# %%
a
# Out:
# 1

# %%
b
# Out:
# 1

# %%
degree_celsius = 0

# %%
degree_celsius +=10
degree_celsius
# Out:
# 10

# %%
import numpy as np

# %%
degree_celsius = 20

# %%
degree_celsius
# Out:
# 20

# %%
no_cats = 60
no_dogs = 70
no_fish = 80
tot_animals = no_cats + no_dogs + no_fish

# %%
tot_animals
# Out:
# 210

# %%
print("Power Star")
# Out:
# Power Star

# %%
abs (-43)
# Out:
# 43

# %%
round(2/3)
# Out:
# 1

# %%
int(3.99)
# Out:
# 3

# %%
abs(round(-2 * 1.5))
# Out:
# 3

# %%
abs(round(-2 * 1.7))
# Out:
# 3

# %%
abs(2*1.7)
# Out:
# 3.4

# %%
help
# Out:
# Type help() for interactive help, or help(object) for help about object.

# %%
help(round)
# Out:
# Help on built-in function round in module builtins:
#
# round(number, ndigits=None)
#     Round a number to a given precision in decimal digits.
#
#     The return value is an integer if ndigits is omitted or None.  Otherwise
#     the return value has the same type as the number.  ndigits may be negative.

# %%
round(5.678)
# Out:
# 6

# %%
round(2/3,3)
# Out:
# 0.667

# %%
round(2/3, 6)
# Out:
# 0.666667

# %%
def c_to_f(degrees_c):
    degrees_f = (9 / 5) * degrees_c + 32
    return degrees_f

# %%
c_to_f(0)
# Out:
# 32.0

# %%
c_to_f(100)
# Out:
# 212.0

# %%
c_to_f(-11)
# Out:
# 12.2

# %%
print("Hello Purushottam")
# Out:
# Hello Purushottam

# %%
def divide(dividend, divisor):
    result = dividend / divisor
    return result

# %%
divide(0, 2)
# Out:
# 0.0

# %%
divide(20, 2)
# Out:
# 10.0
